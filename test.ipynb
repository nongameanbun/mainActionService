# %%
from gateway import *
from utils.position import *

sys = {
            "movement" : "tel",
            "main_attack_key" : "s",
            "doping_key" : "f12",
            
            "npc_key" : "space",
            "rope_key" : "z",
            "fountain_key" : "num6",
            "jump_key" : "left_alt",
            "tel_key" : "left_shift",

            "originkey" : "num2",
            "skill_key" : "k",
            "inven_key" : "i",
            "battle_statistics_key" : "num_minus",
            "ascent_key" : "num3",
            "ascent_num" : 3,

            "dead_potion_key" : "f6",
            "millage_key" : "f7",
            "elbo_reward_key" : "f8",
        }

check_pos()
# Out:
# [34, 116]

# %%
on()
for _ in range(4*(5+3*prob(50)+2*prob(25)+prob(10))) :
    press_key_with_delay("s", 60)
    Rdelay_2(100)
off()

# %%
on()
Rdelay_2(1000)
tel_left("s", "left_shift")
off()
