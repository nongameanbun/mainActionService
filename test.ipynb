# %%
from utils.rune import *
print(autorune())
# Out:
# None
# Rune solution is not complete. Retrying...
# None
# Rune solution is not complete. Retrying...
# None
# Rune solution is not complete. Retrying...
# None
# Rune solution is not complete. Retrying...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 from utils.rune import *
# ----> 2 print(autorune())
#
# File c:\Users\inho9\Desktop\WEEING_INTEGRATION\250307\mainAction\utils\rune.py:22, in autorune(stack)
#      20     print("Rune solution is not complete. Retrying...")
#      21     time.sleep(4)
# ---> 22     autorune(stack=stack+1)
#      24 for arrow in res:
#      25     press_key_with_delay(arrow, 100)
#
# File c:\Users\inho9\Desktop\WEEING_INTEGRATION\250307\mainAction\utils\rune.py:22, in autorune(stack)
#      20     print("Rune solution is not complete. Retrying...")
#      21     time.sleep(4)
# ---> 22     autorune(stack=stack+1)
# ...
